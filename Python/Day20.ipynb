# %%
import pandas as pd

# %%
bc_data = pd.read_csv('data.csv')

# %%
bc_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Drop unnecessary columns
bc_data.drop('id', axis=1, inplace=True)

# %%
# Encode the target variable 'diagnosis' (M or B)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
bc_data['diagnosis'] = le.fit_transform(bc_data['diagnosis'])

# %%
bc_data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
print(bc_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int32
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
print(bc_data['diagnosis'].value_counts())
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
# 1 Malignant
# 0 Benign

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Data Visualization
sns.pairplot(bc_data, hue='diagnosis', vars=['radius_mean', 'texture_mean', 'area_mean'])
plt.show()

# %%
# Example
sns.countplot(x='diagnosis', data=bc_data)
plt.title('Distribution of Diagnosis')
plt.show()

# %%
# Correlation
correlation_matrix = bc_data.corr()
plt.figure(figsize=(23, 19))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Feature Correlation')
plt.show()

# %%
plt.figure(figsize=(24, 12))
for i, column in enumerate(bc_data.select_dtypes(include='number').columns, 1):
    plt.subplot(2, 4, i)
    sns.boxplot(x='diagnosis', y=column, data=bc_data)
    plt.title(f'Boxplot of {column} by Diagnosis')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 plt.figure(figsize=(24, 12))
#       2 for i, column in enumerate(bc_data.select_dtypes(include='number').columns, 1):
# ----> 3     plt.subplot(2, 4, i)
#       4     sns.boxplot(x='diagnosis', y=column, data=bc_data)
#       5     plt.title(f'Boxplot of {column} by Diagnosis')
#
# File c:\users\s.s.s.dhyuthidhar\appdata\local\programs\python\python38\lib\site-packages\matplotlib\pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# ...
