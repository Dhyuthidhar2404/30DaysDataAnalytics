# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris_df = sns.load_dataset('iris')

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Pair plot for EDA
sns.pairplot(iris_df, hue='species')
plt.show()

# %%
# Box plots for feature comparison
plt.figure(figsize=(12, 6))
sns.boxplot(x='species', y='petal_length', data=iris_df)
plt.title('Comparison of Petal Lengths across Species')
plt.show()

# %%
# Box plots for feature comparison
plt.figure(figsize=(12, 6))
sns.boxplot(x='species', y='petal_width', data=iris_df)
plt.title('Comparison of Petal Lengths across Species')
plt.show()

# %%
# Box plots for feature comparison
plt.figure(figsize=(12, 6))
sns.boxplot(x='species', y='sepal_length', data=iris_df)
plt.title('Comparison of Petal Lengths across Species')
plt.show()

# %%
# Box plots for feature comparison
plt.figure(figsize=(12, 6))
sns.boxplot(x='species', y='sepal_width', data=iris_df)
plt.title('Comparison of Petal Lengths across Species')
plt.show()

# %%
correlation_matrix = iris_df.corr()
print(correlation_matrix)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000
# C:\Users\S.S.S.Dhyuthidhar\AppData\Local\Temp\ipykernel_26192\1247400854.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = iris_df.corr()

# %%
# Correlation heatmap
correlation_matrix = iris_df.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# sepal length is highly correlated to petal length and petal widht so as the sepal length increases petal length will increase as well as petal widht also. And petal length is highly correlated with sepal length and petal width so as the petal length increases sepal length will increase as well as petal width also increase and petal widht is highly correlated with sepal length and petal length so petal width increases sepal length will increase as well as petal length will increase

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

x = iris_df.drop('species',axis=1)
y = iris_df.species

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)

accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 1.00

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
iris_df['Cluster'] = kmeans.fit_predict(x)

# Scatter plot of clustered data
sns.scatterplot(x='petal_length', y='petal_width', hue='Cluster', data=iris_df)
plt.title('K-Means Clustering of Iris Dataset')
plt.show()
